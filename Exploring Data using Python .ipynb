# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing the extracted Data Sets
# (Syria_joined_table.csv)

# %%
data = pd.read_csv('Syria_joined_table.csv')
data.head()
# Out:
#    year  global_avg_temp  city_avg_temp
# 0  1808             7.63          14.91
# 1  1809             7.08          17.04
# 2  1810             6.92          17.09
# 3  1811             6.86          17.12
# 4  1812             7.05          17.07

# %%
# function that calculates the moving average 
def moving_avg(mA_range, data_input):  
    output = data_input.rolling(window = mA_range, center = False, on = 'city_avg_temp').mean().dropna()
    return output

# Function Calling with the range of Moving Average
mA_value = 150
chart_moving_avg = moving_avg(mA_value, data)

# %%
plt.plot(chart_moving_avg['year'], chart_moving_avg['global_avg_temp'], label='Global')
plt.legend()
plt.xlabel('Years')
plt.ylabel(u'Temperature (°C)' )
plt.title("Global Average Temperature")
plt.show()

# %%
# Drawing the graph: damascus and Global Temperature
plt.plot(chart_moving_avg['year'], chart_moving_avg['city_avg_temp'], label='Damascus',c='r')
plt.plot(chart_moving_avg['year'], chart_moving_avg['global_avg_temp'], label='Global',c='b')
plt.legend()
plt.xlabel("Years")
plt.ylabel(u"Temperature (°C)")
plt.title("Damascus Vs Global Average Temperature")
plt.show()

# %%
data.tail(10)
# Out:
#      year  global_avg_temp  city_avg_temp
# 196  2004             9.32          19.22
# 197  2005             9.70          19.15
# 198  2006             9.53          19.07
# 199  2007             9.73          19.47
# 200  2008             9.43          19.75
# 201  2009             9.51          19.60
# 202  2010             9.70          21.07
# 203  2011             9.52          18.95
# 204  2012             9.51          19.72
# 205  2013             9.61          19.83

# %%
data.head(10)
# Out:
#    year  global_avg_temp  city_avg_temp
# 0  1808             7.63          14.91
# 1  1809             7.08          17.04
# 2  1810             6.92          17.09
# 3  1811             6.86          17.12
# 4  1812             7.05          17.07
# 5  1813             7.74          17.62
# 6  1814             7.59          17.68
# 7  1815             7.24          17.42
# 8  1816             6.94          16.97
# 9  1817             6.98          17.15
